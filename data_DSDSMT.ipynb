# %% [markdown]
# <a href="https://colab.research.google.com/github/zoebatz/CAP6671_project/blob/main/data_DSDSMT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Labels:
#
# 0 = severly depressed
#
# 1 = moderately depressed
#
# 2 = not depressed

# %%
import pandas as pd

# %%
url_train = 'https://raw.githubusercontent.com/rafalposwiata/depression-detection-lt-edi-2022/refs/heads/main/data/preprocessed_dataset/train.csv'

train_data = pd.read_csv(url_train)
train_data.head()
# Out:
#               pid                                               text  labels
# 0  train_pid_7991  At this point just genuinely curious what sort...       0
# 1  train_pid_7992  I have literally tried everything.... : I'm st...       0
# 2  train_pid_7995  I'm really struggling : So I don't know how to...       0
# 3  train_pid_7996  My meds aren’t making my depression any better...       0
# 4  train_pid_7997  Hi I'm unwell : I'm 21 now, "vice ridden", and...       0

# %%
# count number of each label
train_data['labels'].value_counts()
# Out:
# labels
# 1    3101
# 2    2255
# 0     650
# Name: count, dtype: int64

# %%
# save train data to drive
train_data.to_csv('/content/drive/MyDrive/Colab Notebooks/data_DSDSMT_train.csv', index=False)

# %%
url_dev = "https://raw.githubusercontent.com/rafalposwiata/depression-detection-lt-edi-2022/refs/heads/main/data/preprocessed_dataset/dev.csv"

dev_data = pd.read_csv(url_dev)
dev_data.head()
# Out:
#             pid                                               text  labels
# 0  dev_pid_4407  I feel so empty : I just broke up with my boyf...       0
# 1  dev_pid_4408  How to cope after decades of depression and no...       0
# 2  dev_pid_4409  How to gain (healthy) weight when in a depress...       0
# 3  dev_pid_4410  Much happier girl now? : Hi guys, for the last...       0
# 4  dev_pid_4411  I don’t know how to help her. : My friend told...       0

# %%
dev_data['labels'].value_counts()
# Out:
# labels
# 1    510
# 2    400
# 0     90
# Name: count, dtype: int64

# %%
# save dev_data to drive
dev_data.to_csv('/content/drive/MyDrive/Colab Notebooks/data_DSDSMT_dev.csv', index=False)

# %%
url_test = "https://raw.githubusercontent.com/rafalposwiata/depression-detection-lt-edi-2022/refs/heads/main/data/preprocessed_dataset/test.csv"

test_data = pd.read_csv(url_test)
test_data.head()
# Out:
#           pid                                               text  labels
# 0  test_pid_1  Im scared : This is it. I lie to myself every ...       1
# 1  test_pid_2  New to this but just wanted to vent : I just f...       1
# 2  test_pid_3  I’m sad : It’s kinda always been an issue. I w...       1
# 3  test_pid_4  Lonely but not alone. : All of my immediately ...       1
# 4  test_pid_5  This year has been trash. : I dont know why I’...       1

# %%
# count number of each label
test_data['labels'].value_counts()
# Out:
# labels
# 1    2169
# 2     848
# 0     228
# Name: count, dtype: int64

# %%
# save test_data to drive
test_data.to_csv('/content/drive/MyDrive/Colab Notebooks/data_DSDSMT_test.csv', index=False)

# %%
# reddit depression corpora used to train their model
reddit_depression_url = "https://github.com/rafalposwiata/depression-detection-lt-edi-2022/blob/main/data/reddit_depression_corpora/reddit_depression_corpora_val.txt"

# txt file to panda dataframe
reddit_depression_data = pd.read_csv(reddit_depression_url, sep="\t")
reddit_depression_data.head()
# Out:
#                                      <!DOCTYPE html>
# 0                                              <html
# 1                                          lang="en"
# 2    data-color-mode="auto" data-light-theme="lig...
# 3    data-a11y-animated-images="system" data-a11y...
# 4                                                  >
