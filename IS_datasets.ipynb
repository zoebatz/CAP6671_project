# %% [markdown]
# <a href="https://colab.research.google.com/github/zoebatz/CAP6671_project/blob/main/IS_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

def read_csv(file_path):
    df = pd.read_csv(file_path)
    return df

file_name = "data_MHSM_20K"
path = "/content/drive/MyDrive/Colab Notebooks/"+file_name+".csv"
df = read_csv(path)
df.head()
# Out:
#                                        original_text  label  \
# 0  It's just over 2 years since I was diagnosed w...      1
# 1  It's Sunday, I need a break, so I'm planning t...      1
# 2  Awake but tired. I need to sleep but my brain ...      1
# 3  RT @SewHQ: #Retro bears make perfect gifts and...      1
# 4  It’s hard to say whether packing lists are mak...      1
#
#                                                 text
# 0  its just over 2 years since i was diagnosed wi...
# 1  its sunday i need a break so im planning to sp...
# 2  awake but tired i need to sleep but my brain h...
# 3  rt retro bears make perfect gifts and are grea...
# 4  its hard to say whether packing lists are maki...

# %%
df.value_counts("label")
# Out:
# label
# 0    10000
# 1    10000
# Name: count, dtype: int64

# %%
# for DSDSMT datasets (relabel to binary, 1 = depress, 0 = not)

if file_name.__contains__("DSDSMT"):
  # count labels
  df['labels'].value_counts()

  # combine moderate and severe labels (0 and 1) and make them 1 and make not depressed = 0
  df['label'] = df['labels'].replace({0: 1, 2: 0}) # old: new

  # shuffle data
  df = df.sample(frac=1, random_state=42).reset_index(drop=True)

df.head()
# Out:
#             pid                                               text  labels  \
# 0  dev_pid_2228  The things that hold me back : A lot of the ti...       1
# 1  dev_pid_3872  I wish I could sleep for a few months : I wish...       2
# 2  dev_pid_3875  Major Depressive Disorder, Alcohol Abuse, and ...       2
# 3  dev_pid_3795  fuck you depression : you know recently i've j...       2
# 4  dev_pid_2118  I feel like I'm falling into insanity : I'm no...       1
#
#    label
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1

# %%
df = df[['text', 'label']]
df.head()
# Out:
#                                                 text  label
# 0  its just over 2 years since i was diagnosed wi...      1
# 1  its sunday i need a break so im planning to sp...      1
# 2  awake but tired i need to sleep but my brain h...      1
# 3  rt retro bears make perfect gifts and are grea...      1
# 4  its hard to say whether packing lists are maki...      1

# %%
df.value_counts("label")
# Out:
# label
# 0    10000
# 1    10000
# Name: count, dtype: int64

# %%
# combine pos and neg and shuffle
df = pd.concat([df_pos, df_neg])
df = df.sample(frac=1).reset_index(drop=True)
df.head()
# Out:
#                                                 text  label
# 0  rft me i have been diagnosed with anxiety and ...      1
# 1  im diagnosed with depression but no one would ...      1
# 2  i usually put the smack down so far i have bee...      1
# 3  help i think i have adhd i have almost all of ...      1
# 4  beady eyes and greedy hearts and now youre mur...      0

# %%
len(df)
# Out:
# 20000

# %%
import os
# create new folder in drive to store clean data (text and label only)
folder_path = "/content/drive/MyDrive/Colab Notebooks/test_metrics"

# Create the folder if it doesn't exist
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
    print(f"Folder created at: {folder_path}")
else:
    print("Folder already exists!")
# Out:
# Folder created at: /content/drive/MyDrive/Colab Notebooks/test_metrics

# %%
file_name
# Out:
# 'data_MHSM_20K'

# %%
# save data
path = "/content/drive/MyDrive/Colab Notebooks/clean_data/clean_MHSM_total.csv"
df.to_csv(path, index=False)

# %%
# load data from drive
path = "/content/drive/MyDrive/Colab Notebooks/clean_data/clean_DSDSMT_test.csv"
df = read_csv(path)
df.head()
# Out:
#                                                 text  label
# 0  I haven't really got much friends : I'm always...      0
# 1         I need a hug : It's been a long long time.      1
# 2  Addiction but not really : I'm not addicted to...      1
# 3  I don't see the point in doing things. : For t...      1
# 4  Do i have fake or real friends? : Hey, really ...      0
